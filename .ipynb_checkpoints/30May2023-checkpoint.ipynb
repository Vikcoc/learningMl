# %%
import pandas as pd
df = pd.read_csv("30Mai2023.csv")
df.drop('Instrument', axis=1, inplace=True)
df.drop('OpenInterest', axis=1, inplace=True)
df.drop('TradeTimestamp', axis=1, inplace=True)
df.drop('Timestamp', axis=1, inplace=True)
for i in range(50):
    df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
    df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
    df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
    df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
    df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
    df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
    df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
df[f'ActualF50'] = df['Actual'].shift(-50) -  df['Actual']
df['ActualF50'] = df['ActualF50'].apply(lambda x: 1 if x >= 1 else -1 if x <= -1 else 0)
df.drop('High', axis=1, inplace=True)
df.drop('Low', axis=1, inplace=True)
df.drop('Actual', axis=1, inplace=True)
df.drop('Volume', axis=1, inplace=True)
df.drop('UsdVolume', axis=1, inplace=True)
df.drop('Change', axis=1, inplace=True)
df.drop('BestBid', axis=1, inplace=True)
df.drop('BestBidSize', axis=1, inplace=True)
df.drop('BestAsk', axis=1, inplace=True)
df.drop('BestAskSize', axis=1, inplace=True)
df = df[50:-10]
df = df.copy()
# Out:
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# ...
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Actual{i+1}'] = df['Actual'].shift(i+1) -  df['Actual']
# /tmp/ipykernel_19619/3431008847.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Volume{i+1}'] = df['Volume'].shift(i+1) - df['Volume']
# /tmp/ipykernel_19619/3431008847.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'Change{i+1}'] = df['Change'].shift(i+1) - df['Change']
# /tmp/ipykernel_19619/3431008847.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBid{i+1}'] = df['BestBid'].shift(i+1) - df['BestBid']
# /tmp/ipykernel_19619/3431008847.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestBidSize{i+1}'] = df['BestBidSize'].shift(i+1) - df['BestBidSize']
# /tmp/ipykernel_19619/3431008847.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAsk{i+1}'] = df['BestAsk'].shift(i+1) - df['BestAsk']
# /tmp/ipykernel_19619/3431008847.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'BestAskSize{i+1}'] = df['BestAskSize'].shift(i+1) - df['BestAskSize']
# /tmp/ipykernel_19619/3431008847.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'ActualF50'] = df['Actual'].shift(-50) -  df['Actual']

# %%
print(df)
# Out:
#       Actual1  Volume1  Change1  BestBid1  BestBidSize1  BestAsk1
# 50      -0.44  -0.0001  -0.0003     -0.38        0.1111     -0.06  \
# 51      -0.10  -0.0707   0.0000     -0.36       -2.1524     -0.28
# 52      -0.18  -0.0500  -0.0001      0.16        2.1524      0.00
# 53       0.09  -0.0580   0.0000     -0.10        0.0000      0.00
# 54      -0.20  -0.0500  -0.0001     -0.08        0.0000     -0.38
# ...       ...      ...      ...       ...           ...       ...
# 1347    -0.24  -0.2204  -0.0002     -0.24        0.2128     -0.24
# 1348     0.82 -18.4653   0.0005      0.76        2.3329      0.27
# 1349    -0.05  -0.0100  -0.0001      0.02        0.0000      0.51
# 1350    -0.38   0.1908  -0.0003     -0.48        0.0446     -0.55
# 1351    -0.05  -0.0500   0.0000      0.02        0.0000      0.01
#
#       BestAskSize1  Actual2  Volume2  Change2  ...  BestAsk49  BestAskSize49
# 50          0.1920    -0.15   6.5059  -0.0007  ...      -2.27         0.1199  \
# 51         -3.2922    -0.54  -0.0708  -0.0003  ...      -2.52        -3.3629
# 52          3.2606    -0.28  -0.1207  -0.0001  ...      -2.61         0.0161
# 53          0.1000    -0.09  -0.1080  -0.0001  ...      -2.60         0.0427
# 54         -0.1456    -0.11  -0.1080  -0.0001  ...      -3.03        -0.1402
# ...            ...      ...      ...      ...  ...        ...            ...
# 1347        3.9069    -0.11  -0.5970  -0.0001  ...      -1.37        -0.0531
# 1348       -2.0360     0.58 -18.6857   0.0003  ...      -1.10        -2.0891
# 1349        2.0891     0.77 -18.4753   0.0004  ...      -0.74        -0.0001
# 1350       -0.2541    -0.43   0.1808  -0.0004  ...      -1.29        -0.0687
# 1351       -0.0157    -0.43   0.1408  -0.0003  ...      -1.38        -0.2698
#
#       Actual50  Volume50  Change50  BestBid50  BestBidSize50  BestAsk50
# 50       -2.49   40.7638    0.0000      -2.40         4.4422      -2.04  \
# 51       -2.73   40.8206   -0.0001      -2.85        -2.1102      -2.55
# 52       -2.78   40.7707   -0.0001      -2.61        -0.0001      -2.52
# 53       -2.51   31.1936   -0.0002      -2.80        -0.0001      -2.61
# 54       -2.91   31.2442   -0.0004      -2.80        -0.0001      -2.98
# ...        ...       ...       ...        ...            ...        ...
# 1347     -1.35   -3.9046   -0.0001      -1.52        -2.2779      -1.35
# 1348     -0.71  -22.3661    0.0003      -0.76         0.0513      -1.10
# 1349     -0.60  -22.3760    0.0002      -0.74         0.0513      -0.59
# 1350     -1.13  -22.0352   -0.0001      -1.22         0.0959      -1.29
# 1351     -1.19  -21.9852   -0.0001      -1.20         0.0959      -1.28
#
#       BestAskSize50  ActualF50
# 50           0.0362          0
# 51          -3.1723          0
# 52          -0.1023          0
# 53           0.1161         -1
# 54          -0.1029          0
# ...             ...        ...
# 1347        -0.0531          0
# 1348        -2.0891          0
# 1349         0.0000          0
# 1350        -0.2542          0
# 1351        -0.0844          0
#
# [1302 rows x 351 columns]

# %%
import os
import pandas as pd
from torch.utils.data import Dataset

class CustomPriceDataset(Dataset):
    def __init__(self, dataframe, labels, transform=None, target_transform=None):
        self.dataframe = dataframe
        self.labels = labels
        self.transform = transform
        self.target_transform = target_transform
        

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        data = list(self.dataframe.iloc[idx])
        label = self.labels.iloc[idx]
        if self.transform:
            data = self.transform(data)
        if self.target_transform:
            label = self.target_transform(label)
        return data, label

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor, Lambda

tstlbl = df['ActualF50'] + 1
tstset = df.drop('ActualF50', axis=1)
testPrice = CustomPriceDataset(tstset, tstlbl, torch.FloatTensor)
test_dataloader = DataLoader(testPrice, batch_size=64)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(350, 2048),
            nn.ReLU(),
            nn.Linear(2048, 1024),
            nn.ReLU(),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Linear(512, 128),
            nn.ReLU(),
            nn.Linear(128, 3),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits
model = torch.load('model2.pth')

# %%
def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
loss_fn = nn.CrossEntropyLoss()
test_loop(test_dataloader, model, loss_fn)
# Out:
# Test Error:
#  Accuracy: 33.8%, Avg loss: 8.216508
